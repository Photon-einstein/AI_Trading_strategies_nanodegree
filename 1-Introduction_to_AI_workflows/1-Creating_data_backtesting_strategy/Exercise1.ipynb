# %% [markdown]
# # Lesson 1: Exercise 1
#
# ## Creating Data and Backtesting a Trading Strategy
#
# ---
#
# ## Overview
#
# Welcome to this Exercise. We are now going to put our skills to the test and create a dataset and prepare our first backtests. Proper data preparation is essential to conducting successful backtest, and we want to make sure that we build a solid foundation and develop proper techniques to ensure that we can build our datasets easily at scale and develop proper data wrangling and preparation approaches. In particular, we are going to cover the  essential steps that are necessary to successfully build trading  models beginning from creating datasets from publicly available stock price data to conducting exploratory data analysis to finally building and testing models. We are then quickly shifts gears and illustrate a few advanced investment ideas that can be used for further analysis.

# %%
import sys
import os

# Manually set the path relative to the py file's location that you want to import
func_lib_path = os.path.abspath(os.path.join(os.getcwd(), '../'))
# Add the path to sys.path
sys.path.append(func_lib_path)
# Now you can import func_lib
import func_lib

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Calculate accuracy, precision, and recall
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
#  Create a variable named 'historical_prices' to store historical price data between the dates'2005-01-01' and '2015-01-01'. Use the function 'createHistPrices()' from 'func_lib' to generate or retrieve the historical prices.
historical_prices = func_lib.create_hist_prices(start_date='2005-01-01', end_date='2015-01-01')
# Create a list named 'list_of_momentums' and add 1 to the list
list_of_momentums = [1]
# Compute the total returns using the historical prices and the list of momentums. Use the 'computingReturns()' function from 'func_lib'. Pass 'historical_prices' and 'list_of_momentums' as arguments to 'func_lib.computingReturns()'.
# - Store the result in a variable named 'total_returns'.
total_returns     = func_lib.compute_returns(historical_prices, list_of_momentums)
# Use the 'dropna()' method on the 'total_returns' DataFrame.
total_returns.dropna(inplace=True)
# Out:
# [***                    6%                       ]  29 of 501 completed$XYZ: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [****                   9%                       ]  44 of 501 completed$HPE: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [******                12%                       ]  59 of 501 completed$DASH: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [******                13%                       ]  63 of 501 completed$TTD: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [*********             19%                       ]  93 of 501 completed$HOOD: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [*********             19%                       ]  96 of 501 completed$VLTO: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [***********           23%                       ]  115 of 501 completed$INVH: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [************          24%                       ]  121 of 501 completed$COIN: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [************          26%                       ]  130 of 501 completed$LITE: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**************        29%                       ]  144 of 501 completed$IR: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**************        30%                       ]  150 of 501 completed$SOLV: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [*****************     36%                       ]  178 of 501 completed$UBER: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [******************    37%                       ]  183 of 501 completed$DOW: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [******************    37%                       ]  185 of 501 completed$CTVA: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [********************  41%                       ]  206 of 501 completed$CRWD: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [********************* 44%                       ]  219 of 501 completed$GEHC: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************45%                       ]  224 of 501 completed$KVUE: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************48%                       ]  241 of 501 completed$ABNB: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************51%                       ]  255 of 501 completed$Q: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************57%**                     ]  286 of 501 completed$KHC: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************61%****                   ]  304 of 501 completed$APP: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************61%****                   ]  308 of 501 completed$PYPL: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************64%******                 ]  322 of 501 completed$OTIS: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************64%******                 ]  323 of 501 completed$SNDK: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************65%******                 ]  326 of 501 completed$HWM: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************66%*******                ]  331 of 501 completed$FOX: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************67%*******                ]  335 of 501 completed$VICI: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************69%********               ]  344 of 501 completed$EXE: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************69%********               ]  347 of 501 completed$VRT: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************71%*********              ]  358 of 501 completed$FOXA: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************72%**********             ]  363 of 501 completed$DELL: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************74%***********            ]  369 of 501 completed$CVNA: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************74%***********            ]  373 of 501 completed$GDDY: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************76%***********            ]  383 of 501 completed$CEG: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************84%***************        ]  422 of 501 completed$GEV: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************85%****************       ]  424 of 501 completed$PLTR: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************86%****************       ]  430 of 501 completed$VST: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************92%*******************    ]  463 of 501 completed$CARR: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************94%********************   ]  469 of 501 completed$FTV: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [**********************97%********************** ]  486 of 501 completed$MRNA: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [*********************100%***********************]  499 of 501 completed$DDOG: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")
# [*********************100%***********************]  501 of 501 completed
#
# 41 Failed downloads:
# ['XYZ', 'HPE', 'DASH', 'TTD', 'HOOD', 'VLTO', 'INVH', 'COIN', 'LITE', 'IR', 'SOLV', 'UBER', 'DOW', 'CTVA', 'CRWD', 'GEHC', 'KVUE', 'ABNB', 'Q', 'KHC', 'APP', 'PYPL', 'OTIS', 'SNDK', 'HWM', 'FOX', 'VICI', 'EXE', 'VRT', 'FOXA', 'DELL', 'CVNA', 'GDDY', 'CEG', 'GEV', 'PLTR', 'VST', 'CARR', 'FTV', 'MRNA', 'DDOG']: possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn't exist for startDate = 1104555600, endDate = 1420088400")

# %%
# Print the first 5 lines of total returns
total_returns.head()
# Out:
#                    F_1_d_returns  1_d_returns
# Ticker Date
# A      2005-01-04      -0.000430    -0.026382
#        2005-01-05      -0.021945    -0.000430
#        2005-01-06      -0.000880    -0.021945
#        2005-01-07      -0.004844    -0.000880
#        2005-01-10      -0.017257    -0.004844

# %%
# Compute cumulative and calendar returns from the total returns data. 
# Use the 'compute_BM_Perf()' function from 'func_lib' to perform this calculation. 
# Pass 'total_returns' as an argument to 'func_lib.compute_BM_Perf()'.
# - The function returns two outputs: 'cum_returns' for cumulative returns and 'calendar_returns' for calendar returns.
# - Assign the outputs to the variables 'cum_returns' and 'calendar_returns' respectively.
cum_returns, calendar_returns = func_lib.compute_BM_Perf(total_returns)
# Out:
# The CAGR is: 16.74%
# Sharpe Ratio of Strategy: 0.8

# %%
# Calculate the Relative Strength Index (RSI) for each 'Ticker' and add it to the 'total_returns' DataFrame.First, group the 'total_returns' DataFrame by the 'Ticker' column.
# For each group, select the '1_d_returns' column and apply a transformation using the 'calculate_rsi' function from 'func_lib'.
# - Assign the result to a new column named 'RSI' in the 'total_returns' DataFrame.
total_returns['RSI'] = total_returns.groupby('Ticker')[['1_d_returns']].transform(func_lib.calculate_rsi)

# %%
# Print out the first 5 rows of the total_returns dataframe
total_returns.head(20)
# Out:
#                    F_1_d_returns  1_d_returns        RSI
# Ticker Date
# A      2005-01-04      -0.000430    -0.026382        NaN
#        2005-01-05      -0.021945    -0.000430        NaN
#        2005-01-06      -0.000880    -0.021945        NaN
#        2005-01-07      -0.004844    -0.000880        NaN
#        2005-01-10      -0.017257    -0.004844        NaN
#        2005-01-11      -0.001351    -0.017257        NaN
#        2005-01-12      -0.021190    -0.001351        NaN
#        2005-01-13       0.015661    -0.021190        NaN
#        2005-01-14       0.017234     0.015661        NaN
#        2005-01-18      -0.016496     0.017234        NaN
#        2005-01-19       0.008613    -0.016496        NaN
#        2005-01-20      -0.020225     0.008613        NaN
#        2005-01-21      -0.016514    -0.020225        NaN
#        2005-01-24       0.016791    -0.016514  21.959250
#        2005-01-25       0.009174     0.016791  32.491070
#        2005-01-26       0.000000     0.009174  35.856660
#        2005-01-27      -0.017727     0.000000  40.590352
#        2005-01-28       0.023137    -0.017727  36.855184
#        2005-01-31       0.018544     0.023137  44.997007
#        2005-02-01       0.007993     0.018544  53.861599

# %%
#  Define a trading strategy function based on the RSI (Relative Strength Index). Create a function named 'trading_strategy' that accepts one parameter: 'rsi'.
# Inside the function, use an if-else statement to implement the trading logic:
#     - If 'rsi' is less than 65, return 1 (indicating a decision to go long).
#     - Otherwise, return 0 (indicating no position or a different strategy).
# - This function will be used later to determine trading actions based on RSI values.
def trading_strategy(rsi : float):
    if rsi < 65:
        return 1    # go long — stock is not overbought
    else:
        return 0    # stay flat — stock may be overextended

# %%
# Create a variable named 'model_name' and set it to the string "RSI".
model_name = "RSI"

# %%
# Compute cumulative and calendar returns for the given trading strategy.
# Use the 'compute_strat_perf()' function from 'func_lib' to perform this calculation.
# Pass 'total_returns', 'cum_returns', 'calendar_returns', 'trading_strategy', and 'model_name' as arguments.
# - The function returns updated 'cum_returns' and 'calendar_returns' based on the strategy's performance.
cum_returns, calendar_returns = func_lib.compute_strat_perf(total_returns, cum_returns, calendar_returns, trading_strategy, model_name)
# Out:
# The CAGR is: 16.54%
# Sharpe Ratio of Strategy: 0.87

# %%
# Create the true values (y_test) indicating whether future 1-day returns (F_1_d_returns) are larger or smaller than 0.
# Use the 'np.where()' function to evaluate the 'F_1_d_returns' column in the 'total_returns' DataFrame.
# Store the result in a new column called 'y_test' in the 'total_returns' DataFrame.

# Copy the values from the 'Position' column of 'total_returns' to a new column named 'y_pred'.

# %%
# Convert the 'y_test' column from the 'total_returns' DataFrame to a list using the 'tolist()' method.
# Store the result in a variable named 'y_test'.
# Similarly, convert the 'y_pred' column to a list and store it in a variable named 'y_pred'.

# %%
# Calculate the accuracy, precision, and recall of the trading strategy.
# - Use the 'accuracy_score()' function to calculate the accuracy of the predictions.
#     - Pass the actual values (y_test) and the predicted values (y_pred) as arguments.
#     - Store the result in a variable named 'accuracy'.
# - Use the 'precision_score()' function to calculate the precision of the predictions.
#     - Similarly, pass 'y_test' and 'y_pred' as arguments.
#     - Store the result in a variable named 'precision'.
# - Use the 'recall_score()' function to calculate the recall of the predictions.
#     - Again, pass 'y_test' and 'y_pred' as arguments.
#     - Store the result in a variable named 'recall'.

# %%
# Create a DataFrame named 'metrics_df' using the 'pd.DataFrame()' function.
# Define a dictionary with two keys: 'Metric' and 'Value'.
#     - The 'Metric' key should have a list of strings: ['Accuracy', 'Precision', 'Recall'].
#     - The 'Value' key should have a list of the calculated metrics: [accuracy, precision, recall].

# %%
# Display the 'metrics_df' DataFrame to see the performance of the trading strategy.
# Out:
#       Metric     Value
# 0   Accuracy  0.511735
# 1  Precision  0.512622
# 2     Recall  0.936336
